# %%
# !curl -L "https://public.roboflow.com/ds/pTmCM2ZiB3?key=5CJyq5j6JL" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip

#http://public.roboflow.com/object-detection/pistols/1/download/yolov5pytorch
# Out:
# 723b3d45fcf5488d50d.txt
#  extracting: export/labels/armas (333)_jpg.rf.eb98f739b68390277b793103a6e999b8.txt
#  extracting: export/labels/armas (1265)_jpg.rf.ea835b144e3b03b8004bae0438d71abb.txt
#  extracting: export/labels/armas (1079)_jpg.rf.ebba5fe35abb9d22e7259279dbc09876.txt
#  extracting: export/labels/armas (2746)_jpg.rf.ec179da475f686b2667aeeea6cfcd068.txt
#  extracting: export/labels/armas (962)_jpg.rf.ec0a6b450cd17c8da42860cd9ae0a1b3.txt
#  extracting: export/labels/armas (970)_jpg.rf.ec9c8a7ebd8af9592907103dd78cefa7.txt
#  extracting: export/labels/armas (834)_jpg.rf.ec674a0a187a6f26f266fe41150492ff.txt
#  extracting: export/labels/armas (1365)_jpg.rf.ec5a615e4d7f284a4c7b14eb2c2cb068.txt
#  extracting: export/labels/armas (694)_jpg.rf.ec5e05319457ec3ca13377eb56ebc97b.txt
#  extracting: export/labels/armas (13)_jpg.rf.ebd56202dca1eb0b562765aeb335b848.txt
#  extracting: export/labels/armas (2532)_jpg.rf.ebe1b93267d6a80e84d74965cf64da99.txt
# ...

# %%
# %cd /content/
# Out:
# [Errno 2] No such file or directory: '/content/'
# /home/minpeter/study/ColabWorkspace

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 6779, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 6779 (delta 47), reused 53 (delta 27), pack-reused 6696
# Receiving objects: 100% (6779/6779), 8.74 MiB | 4.29 MiB/s, done.
# Resolving deltas: 100% (4654/4654), done.

# %%
# %cd /content/yolov5/
# Out:
# [Errno 2] No such file or directory: '/content/yolov5/'
# /home/minpeter/study/ColabWorkspace

# %%
# !pip install -r requirements.txt
# Out:
# zsh:1: command not found: pip

# %%
# %cd /content/
# Out:
# [Errno 2] No such file or directory: '/content/'
# /home/minpeter/study/ColabWorkspace

# %%
# %ls
# Out:
#  README.dataset.txt                        data.yaml   npandplt.ipynb
#  README.roboflow.txt                       export/     yolov5/
# '_Matplotlib 한번에 제대로 배우기.ipynb'   gun.ipynb

# %%
# %cat /content/dataset/data.yaml
# Out:
# cat: /content/dataset/data.yaml: No such file or directory

# %%
from glob import glob
img_list = glob('/content/dataset/export/images/*.jpg')
print(len(img_list))
# Out:
# 0

# %%
from sklearn.model_selection import train_test_split
train_img_list, val_img_list = train_test_split(img_list, test_size=0.2, random_state=2000)
print(len(train_img_list), len(val_img_list))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-c6c299f5541e> in <module>
# ----> 1 from sklearn.model_selection import train_test_split
#       2 train_img_list, val_img_list = train_test_split(img_list, test_size=0.2, random_state=2000)
#       3 print(len(train_img_list), len(val_img_list))
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
with open('/content/dataset/train.txt', 'w') as f:
  f.write("\n".join(train_img_list) + '\n')

with open('/content/dataset/val.txt', 'w') as f:
  f.write("\n".join(val_img_list) + 'wn')

# %%
import yaml

with open('/content/dataset/data.yaml', 'r') as f:
  data = yaml.load(f)

print("data")

data['train'] = '/content/dataset/train.txt'
data['val'] = '/content/dataset/val.txt'

with open('/content/dataset/data.yaml','w') as f:
  yaml.dump(data, f)
print(data)
# Out:
# data
# {'train': '/content/dataset/train.txt', 'val': '/content/dataset/val.txt', 'nc': 1, 'names': ['pistol']}
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   after removing the cwd from sys.path.

# %%
# %cd /content/yolov5/
# Out:
# /content/yolov5

# %%
# !python train.py --img 416 --batch 16 --epochs 50 --data /content/dataset/data.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name gun_yolov5s_results
# Out:
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/ultralytics/yolov5
#    2cc0a76..810e5d3  glenn-jocher-patch-5 -> origin/glenn-jocher-patch-5
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v5.0-79-gd6a71ae torch 1.8.1+cu101 CUDA:0 (Tesla K80, 11441.1875MB)
#
# ...
