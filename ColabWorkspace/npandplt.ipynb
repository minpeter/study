# %%
import numpy as np

data1 = [1,2,3,4,5]
print(data1)
data2 = [1,2,3,3,5,4]
print(data2)


arr1 = np.array(data1)
print(arr1)

arr2 = np.array(data1)

arr2.dtype

np.zeros(10)
np.zeros((3,5))

onedd = np.ones((2,3))

(np.arange(10) *2) ** 2
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 3, 3, 5, 4]
# [1 2 3 4 5]
# array([  0,   4,  16,  36,  64, 100, 144, 196, 256, 324])

# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.linspace(0, 1, 5)

plt.plot(a, 'x')
plt.show()

# %%
a = np.random.rand(10000)
plt.hist(a,bins=10)
plt.show()

# %%
data = np.random.randn(10000)
print(a)
plt.hist(data, bins=10)
plt.show()
# Out:
# [0.54210216 0.41176147 0.77560601 ... 0.19392127 0.75262906 0.74394695]
